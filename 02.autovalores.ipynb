# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['figure.figsize'] = (7,7)

# %%
# %run "0.utils.py""

# %%
X = np.array([[3,2], [4,1]])
print(X)
# Out:
# [[3 2]
#  [4 1]]

# %%
v = np.array([[1], [1]])
print(v)
# Out:
# [[1]
#  [1]]

# %%
u = X @ v
print(u)
# Out:
# [[5]
#  [5]]

# %%
graph_vectores([u.flatten(), v.flatten()])

# %%
s = np.array([[-1], [2]])
t = X @ s
print(t)
# Out:
# [[ 1]
#  [-2]]

# %%
graph_vectores((t.ravel(), s.ravel()))
